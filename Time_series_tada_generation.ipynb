# %% [markdown]
# <a href="https://colab.research.google.com/github/Daivar/Deep_Learning_Models/blob/main/Time_series_tada_generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt 

def plot_time_series(time, values, label):
    plt.figure(figsize=(30,6))
    plt.plot(time, values)
    plt.xlabel("Time", fontsize=20)
    plt.ylabel("Value", fontsize=20)
    plt.title(label, fontsize=20)
    plt.grid(True)

# %%
l1 = list(range(6))
l2 = [5.99, 6.99, 7.66, 8.11, 7.66, 8.11]

plot_time_series(l1, l2, "Simple")

# %%
data = {'ind': ['prior110', 'prior113', 'prior118', 'prior141', 'prior144', 'prior16', 'prior217', 'prior223', 'prior245', 'prior29', 'prior352', 'prior360', 'prior370', 'prior438', 'prior55', 'prior59', 'prior60', 'prior68', 'prior74', 'prior88'],
        'val': [13.96217, 10.861125, 21.304131, 11.309109, 11.363863, 14.479841, 10.403186, 14.201095, 7.974116, 17.401692, 9.860627, 12.339472, 16.207068, 16.381284, 20.587357, 10.452962, 15.828771, 16.769537, 16.918865, 9.805874]}
prior_fails = pd.DataFrame(data, columns=['ind', 'val'])
prior_fails.set_index('ind', inplace=True)
print(prior_fails.index)
plot_time_series(prior_fails.index, prior_fails[['val']], 'Line plot')
# Out:
# Index(['prior110', 'prior113', 'prior118', 'prior141', 'prior144', 'prior16',
#        'prior217', 'prior223', 'prior245', 'prior29', 'prior352', 'prior360',
#        'prior370', 'prior438', 'prior55', 'prior59', 'prior60', 'prior68',
#        'prior74', 'prior88'],
#       dtype='object', name='ind')

# %%
import pandas as pd
import numpy as np

data = pd.Series(abs(np.random.randn(100)))
plot_time_series(data.index, data, "Random")

# %%
time = np.arange(100)
values = time * 50
plot_time_series(time, values, "Upward Trend")

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

x = np.arange(0,3 * np.pi, 0.1)
# print(x)
y = np.sin(x) ** 2 
# y = np.cos(x) ** 2
# y = np.tan(x)
plt.plot(x,y)
plt.title("SINE WAVE")
plt.show()

# %%
x = np.arange(0,3 * np.pi, 0.1)
y = np.sin(x) ** 2 

# generate the possition where should we insert the anomally, randomly
possition_to_insert = np.random.randint(low=0, high=len(y))
# generate the actuall number, we are going to replace the real number with
diggit_to_insert = random.uniform(y.min(), y.max())
# print("min: {}, max: {}".format(y.min(), y.max()))
y[possition_to_insert] = diggit_to_insert

plt.plot(x,y)
plt.title("SINE WAVE W/ ANOMALLY")
plt.show()

# %%
x = np.arange(0,3 *np.pi, 0.1)
y = np.sin(x) ** 2

def anomalyse(data, possitions, values):
  for i, value in enumerate(values):
    data[possitions[i]] = value 
  return data

pos1 = np.random.randint(low=0, high=len(y))
pos2 = np.random.randint(low=0, high=len(y))
pos3 = np.random.randint(low=0, high=len(y))

dig1 = random.uniform(y.min(), y.max())
dig2 = random.uniform(y.min(), y.max())
dig3 = random.uniform(y.min(), y.max())

plt.plot(x,anomalyse(y, [pos1, pos2, pos3], [dig1, dig2, dig3]))
plt.title("SINE WAVE W/ ANOMALLY")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0,10,0.01) # Return evenly spaced values within a given interval
x2 = np.arange(0,25,0.025) # Generate another range. The nimber of values generated has to be the same as x

sin1 = np.sin(x)
sin2 = np.sin(x2)

# x2 /= 2

sin3 = sin1 + sin2

plt.plot(x,sin1)
plt.show()
plt.plot(x,sin2)
plt.show()
plt.plot(x,sin3)
plt.show()

# sin4 = sin3 + sin2
# plt.plot(x,sin4)
# plt.show()

# %%
x = np.arange(0, 200, 0.1)
x2 = np.arange(0, 20, 0.01)

sin1 = np.sin(x)
sin2 = np.sin(x2)

plt.plot(x, sin1 / 20)
plt.show()
plt.plot(x,sin2)
plt.show()

# sin3 = sin1 + sin2 
# plt.plot(x, sin3)
# plt.show()

sin3 = sin1 / 22.5 + sin2
plt.plot(x, sin3)
plt.show()

# %%
x = np.asarray([10,4,30,5,40,6], dtype=np.float32)
y = np.where(x < 10, x * 3, x + 2) # ([condition], [generator if true], [generator if false])

print(x)
print(y)
# Out:
# [10.  4. 30.  5. 40.  6.]
# [12. 12. 32. 15. 42. 18.]

# %%
import numpy as np

# Just a random pattern
time = np.arange(50)

values = np.where(time < 10, time ** 3, (time-9) ** 2)

values_needed = 250

# Repeat the pattern 5 times
seasonal = []
for i in range(int(values_needed / 50)):
    for j in range(50):
        seasonal.append(values[j])
# Plot
time_seasonal = np.arange(values_needed)
plot_time_series(time_seasonal, seasonal, label="Seasonality")

# %%
# Combination

x = np.arange(0, 500, 0.02)
y = np.sin(x)

y = y * 5 + np.arange(0,500,0.02) * 1
#  # sinusoidal seasonality with trend
plot_time_series(x, y, "Upward Trend")

# %%
import numpy as np

x = np.arange(0, 200, 0.1)
x2 = np.arange(0, 20, 0.01)

sin1 = np.sin(x)
sin2 = np.sin(x2)

# sin3 = (sin1 / 10 + sin2) * 800 + np.arange(0,400,0.2)
sin3 = (sin1 / 20 + sin2) * 800 + np.arange(0,400,0.2)

plt.plot(x, sin3)
plt.show()

# %%
noise = np.random.randn(250) * 100
seasonal += noise
seasonal_upward = seasonal + np.arange(250) * 10
time_seasonal = np.arange(250)
plot_time_series(time_seasonal, seasonal_upward, label="Seasonality + Upward Trend + Noise")

# %%
from pandas import read_csv
# reading from the URL directly
url = 'https://raw.githubusercontent.com/MindaugasBernatavicius/DeepLearningCourse/master/09_Sequential_Data_Analysis/melbourne_min_daily_temps.csv'
series = read_csv(url)
print(series.head())
# Out:
#          Date  Temp
# 0  1981-01-01  20.7
# 1  1981-01-02  17.9
# 2  1981-01-03  18.8
# 3  1981-01-04  14.6
# 4  1981-01-05  15.8

# %%
from matplotlib import pyplot

series.plot()

series.plot(figsize=(25,10))
pyplot.show()

# %%
series.plot(figsize=(20,10), style='r.') # k- k. r-

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
pip install timesynth==0.2.4
# Out:
# ...
#      |████████████████████████████████| 11.2 MB 26.8 MB/s
# ...
#      |████████████████████████████████| 136 kB 52.9 MB/s
# ...
#   Created wheel for jitcdde: filename=jitcdde-1.4.0-py3-none-any.whl size=30678 sha256=de886c2f5a84ea8981e590d155d8d80964b376a8232791a68995fc424d1b0f3d
#   Stored in directory: /root/.cache/pip/wheels/cf/d2/77/59125d6954137b752084445b1bcd72f134af900a3ed3c49de6
# ...
#   Created wheel for jitcxde-common: filename=jitcxde_common-1.4.1-py3-none-any.whl size=14959 sha256=1231d654e0d4a0e54eb5e4883f869732058d4d306555e1f6fe0e5db25c471048
#   Stored in directory: /root/.cache/pip/wheels/79/e2/7b/ce32a30ff68c0d9c7495f9580af1a24ef7c33779bd86cdcc91
# Successfully built jitcdde jitcxde-common
# ...

# %%
import timesynth as ts

# %%
# Initializing TimeSampler
time_sampler = ts.TimeSampler(stop_time=20)
# Sampling irregular time samples
irregular_time_samples = time_sampler.sample_irregular_time(num_points=500, keep_percentage=50)

# %%
# Initializing Sinusoidal signal
sinusoid = ts.signals.Sinusoidal(frequency=0.25)

# %%
# Initializing Gaussian noise
white_noise = ts.noise.GaussianNoise(std=0.1)

# %%
# Initializing TimeSeries class with the signal and noise objects
timeseries = ts.TimeSeries(sinusoid, noise_generator=white_noise)

# %%
# Sampling using the irregular time samples
samples, signals, errors = timeseries.sample(irregular_time_samples)

# %%
# Plotting the series
plt.figure(figsize=(20,6))
plt.plot(irregular_time_samples, samples, marker='o', markersize=5)
plt.plot(irregular_time_samples, signals, marker='o', markersize=5)
plt.plot(irregular_time_samples, errors, marker='o', markersize=5)
plt.xlabel('Time')
plt.ylabel('Magnitude')
plt.title('Irregularly sampled sinusoid with noise');

# %%
url = 'https://raw.githubusercontent.com/MindaugasBernatavicius/DeepLearningCourse/master/09_Sequential_Data_Analysis/melbourne_min_daily_temps.csv'

# create a scatter plot
from pandas import read_csv
from matplotlib import pyplot
from pandas.plotting import lag_plot
series = read_csv(url, header=0, index_col=0, parse_dates=True, squeeze=True)
series.plot()

# %%
lag_plot(series, lag=1)
pyplot.show()

lag_plot(series, lag=180) # 180 - negativelly correlated
pyplot.show()

# %%
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from matplotlib import pyplot
from pandas.plotting import scatter_matrix

url = 'https://raw.githubusercontent.com/MindaugasBernatavicius/DeepLearningCourse/master/09_Sequential_Data_Analysis/melbourne_min_daily_temps.csv'

series = read_csv(url, header=0, index_col=0, parse_dates=True, squeeze=True)
values = DataFrame(series.values)
lags = 7
columns = [values]

for i in range(1,(lags + 1)):
	columns.append(values.shift(i))
dataframe = concat(columns, axis=1)
columns = ['t+1']
for i in range(1,(lags + 1)):
	columns.append('t-' + str(i))
dataframe.columns = columns
pyplot.figure(1, figsize=(20, 10))

for i in range(1,(lags + 1)):
	ax = pyplot.subplot(240 + i)
	ax.set_title('t+1 vs t-' + str(i))
	pyplot.scatter(x=dataframe['t+1'].values, y=dataframe['t-'+str(i)].values)
pyplot.show()

# %%
import time as t
for i in range(1, 181):
  lag_plot(series, lag=i * 30)
  pyplot.show()
  t.sleep(0.2)

# %%
from pandas import read_csv
from pandas import DataFrame
from pandas import Grouper
from matplotlib import pyplot

url = 'https://raw.githubusercontent.com/MindaugasBernatavicius/DeepLearningCourse/master/09_Sequential_Data_Analysis/melbourne_min_daily_temps.csv'
series = read_csv(url, header=0, index_col=0, parse_dates=True, squeeze=True)

groups = series.groupby(Grouper(freq='A'))
# print(list(groups))

years = DataFrame()
for name, group in groups:
	# print(group.values)
	# print(name)
	years[name.year] = group.values

# years
years.plot(figsize=(20,35), subplots=True, legend=False)
pyplot.show()

# %%
series.hist(figsize=(20,5), bins = 100)
pyplot.show()

# %%
series.plot(figsize=(20,5), kind='kde')
pyplot.show()

# %%
groups = series.groupby(Grouper(freq='A'))
years = DataFrame()
for name, group in groups:
	years[name.year] = group.values
years.boxplot(figsize=(20,5), whis=2)
pyplot.show()

# %%
# Autocorelation

import pandas as pd
from pandas.plotting import autocorrelation_plot
from pandas import read_csv
from matplotlib import pyplot as plt

x = np.arange(0, 30, 0.1)
sin1 = np.sin(x)

plt.figure(figsize=(10, 5))
plt.plot(x, sin1)
plt.show()

plt.figure(figsize=(10, 5))
autocorrelation_plot(sin1) # [100:200]

# %%
noise = pd.Series(np.random.randn(250)*100)
noise.plot(figsize=(12,6))

pyplot.figure(figsize=(12,6))
autocorrelation_plot(noise)

# %%
from statsmodels.graphics.tsaplots import plot_acf
from matplotlib import pyplot as plt
import statsmodels.api as sm

series = read_csv(url, header=0, index_col=0)
fig, ax = plt.subplots(figsize=(18,5))
sm.graphics.tsa.plot_acf(series, ax=ax, lags=len(series)-1);



pyplot.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
